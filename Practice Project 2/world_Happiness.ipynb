# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("world_happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Observation : This is a Regression Problem

# %%
#Checking Top 5 Rows

df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Checking Last 5 Rows
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# Checking Null Values

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Observation : As no null value present so need of Nan Value treatment .

# %%
#Heatmap of null values

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Gather all columns

df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# all information about data

df.info
# Out:
# <bound method DataFrame.info of          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
#checking data types

df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Checking Statistical Summary :

df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# All statistical data of all rows shown for each parameters like mean, minimum, maximum , 25th percentile means how much value for each column are below 25th percentile ,similarly for 50th perecntile and 75th perecntile.

# %%
# Defining Columns as nominal data and ordinal data

# %%
df_visualization_nominal=df[['Country','Region']].copy()
df_visualization_nominal.columns
# Out:
# Index(['Country', 'Region'], dtype='object')

# %%
df_visualization_ordinal=df[["Happiness Rank","Happiness Score","Standard Error","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual"]].copy()
df_visualization_ordinal.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
### For nominal data we draw countplot and for ordinal data we draw distribution plot ###

# %%
sns.set()                                                                  ## For showing grid lines in graph

# %% [markdown]
# # EDA :

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
## COUNTPLOTS for Nominal data :

# %%
# Country Column

sns.countplot(x="Country",data=df_visualization_nominal)
plt.title("Country Names")
plt.show()

df['Country'].value_counts()
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64

# %% [markdown]
# Observation : There are individual countries so respresentation is not possible

# %%
# Region Column

sns.countplot(x="Region",data=df_visualization_nominal)
plt.title("Region")
plt.show()

df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# Observation : Values for each region shown in graph.

# %%
## DISTRIBUTIONPLOTS for Ordinal data :

# %%
# Happiness Rank Column

sns.distplot(df['Happiness Rank'])
plt.title("Happiness Rank")
plt.show()

# %% [markdown]
# Observation : There is no skewness . This is almost bell shaved curve

# %%
# Happiness Score Column

sns.distplot(df['Happiness Score'])
plt.title("Happiness Score")
plt.show()

# %% [markdown]
# Observation : Mostly score values lies in range of 4-6

# %%
# Standard Error Column

sns.distplot(df['Standard Error'])
plt.title("Standard Error")
plt.show()

# %% [markdown]
# Observation : Error lies in range of 0.04 to 0.06

# %%
# Economy (GDP per Capita) Column

sns.distplot(df['Economy (GDP per Capita)'])
plt.title("Economy (GDP per Capita)")
plt.show()

# %% [markdown]
# Observation : There is some left skewness present.

# %%
# Family Column

sns.distplot(df['Family'])
plt.title("Family")
plt.show()

# %% [markdown]
# Observation : Left Skewness and family value in range of 1.00-1.25

# %%
# Health (Life Expectancy) Column

sns.distplot(df['Health (Life Expectancy)'])
plt.title("Health (Life Expectancy)")
plt.show()

# %% [markdown]
# Observation : Left Skewness and Health value in range of 0.6-0.9

# %%
# Freedom Column

sns.distplot(df['Freedom'])
plt.title("Freedom")
plt.show()

# %%
# Trust (Government Corruption) Column

sns.distplot(df['Trust (Government Corruption)'])
plt.title("Trust (Government Corruption)")
plt.show()

# %% [markdown]
# observation : right skewed data and values lies in range of 0.0 to 0.2

# %%
# Generosity Column

sns.distplot(df['Generosity'])
plt.title("Generosity")
plt.show()

# %% [markdown]
# observation : Values lies in range of 0.1 to 0.3

# %%
# Dystopia Residual Column

sns.distplot(df['Dystopia Residual'])
plt.title("")
plt.show()

# %% [markdown]
# Observation : It is bell shaped curve so almost symmetric.

# %% [markdown]
# BIVARIATE ANALYSIS

# %% [markdown]
# We check input parameters with output measure "Happiness Score" through Bar Plots for object column :

# %%
# Region vs Happiness Score

sns.barplot(x='Happiness Score',y='Region',data=df)
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Region'>

# %% [markdown]
# This is inverse relation

# %%
## SCATTER PLOT For Continuous Data

# %%
# Dystopia Residual Scatter Plot

plt.scatter(df['Dystopia Residual'],df['Happiness Score'])

# %% [markdown]
# Observation : - Dystopia Residual Vlaues 1.5-3 mostly concentrated in Happiness Score range 4-7

# %%
# Standard Error Scatter Plot

plt.scatter(df['Standard Error'],df['Dystopia Residual'])

# %% [markdown]
# Observation : - Standard Error Vlaues 0.4-0.6 mostly concentrated in Dystopia Residual range 1.5-3.0

# %%
# Economy (GDP per Capita) Scatter plot

plt.scatter(df['Economy (GDP per Capita)'],df['Happiness Score'])

# %% [markdown]
# Observation : - Economy (GDP per Capita) Vlaues 0.25-1.25 mostly concentrated in Happiness Score range 4-7

# %%
# Family Scatter plot
plt.scatter(df['Family'],df['Happiness Score'])

# %% [markdown]
# Observation : - Family Vlaues 0.8-1.3 mostly concentrated in Happiness Score range 4-7

# %%
# Health (Life Expectancy) Scatter Plot

plt.scatter(df['Health (Life Expectancy)'],df['Happiness Score'])

# %% [markdown]
# Observation : - Health (Life Expectancy) Vlaues 0.6-0.9 mostly concentrated in Happiness Score range 4-7

# %%
# Trust (Government Corruption) Scatter Plot

plt.scatter(df['Trust (Government Corruption)'],df['Happiness Score'])

# %% [markdown]
# Observation : - Trust (Government Corruption) Vlaues 0.0-0.2 mostly concentrated in Happiness Score range 4-7

# %%
# Generosity Scatter Plot

plt.scatter(df['Generosity'],df['Happiness Score'])

# %% [markdown]
# Observation : - Generosity Vlaues 0.1-0.4 mostly concentrated in Happiness Score range 4-7

# %% [markdown]
# * MULTIVARIATE ANALYSIS

# %%
#check data distribution among all coulmns

df.plot(kind='density',subplots=True,layout=(2,5),sharex=False,legend=True,figsize=(18,10))
plt.show()

# %%
df=df.drop(['Country','Happiness Rank'],axis=1)                       # Delete these 2 columns as nominl data
df
# Out:
#                               Region  Happiness Score  Standard Error  \
# 0                     Western Europe            7.587         0.03411
# 1                     Western Europe            7.561         0.04884
# 2                     Western Europe            7.527         0.03328
# 3                     Western Europe            7.522         0.03880
# 4                      North America            7.427         0.03553
# ..                               ...              ...             ...
# 153               Sub-Saharan Africa            3.465         0.03464
# 154               Sub-Saharan Africa            3.340         0.03656
# 155  Middle East and Northern Africa            3.006         0.05015
# 156               Sub-Saharan Africa            2.905         0.08658
# 157               Sub-Saharan Africa            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# # Encoding Categorical columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0         9            7.587         0.03411                   1.39651
# 1         9            7.561         0.04884                   1.30232
# 2         9            7.527         0.03328                   1.32548
# 3         9            7.522         0.03880                   1.45900
# 4         5            7.427         0.03553                   1.32629
# ..      ...              ...             ...                       ...
# 153       8            3.465         0.03464                   0.22208
# 154       8            3.340         0.03656                   0.28665
# 155       4            3.006         0.05015                   0.66320
# 156       8            2.905         0.08658                   0.01530
# 157       8            2.839         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# # Correlation :

# %%
#Now we check correlation of input parameters with output "quality" :
#positively correlated : direct correlation
#negatively correlated : negative correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                                  Region  Happiness Score  Standard Error  \
# Region                         1.000000        -0.176791       -0.022600
# Happiness Score               -0.176791         1.000000       -0.177254
# Standard Error                -0.022600        -0.177254        1.000000
# Economy (GDP per Capita)      -0.260139         0.780966       -0.217651
# Family                        -0.168533         0.740605       -0.120728
# Health (Life Expectancy)      -0.357508         0.724200       -0.310287
# Freedom                        0.092567         0.568211       -0.129773
# Trust (Government Corruption)  0.165040         0.395199       -0.178325
# Generosity                     0.273557         0.180319       -0.088439
# Dystopia Residual             -0.057276         0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.260139 -0.168533
# ...

# %%
# For better understanding of correlation matrix between columns we draw heatmap :

plt.figure(figsize=(10,4))
sns.heatmap(dfcor,annot=True)
# Out:
# <Axes: >

# %%
# We can change color also and decimal values place :

plt.figure(figsize=(8,6))
sns.heatmap(dfcor,annot=True,cmap='Blues',fmt='0.2f',cbar=True,square=False)
# Out:
# <Axes: >

# %%
#Correlation of all columns with the target column 'Happiness Score':

# %%
df.corr()["Happiness Score"].sort_values()
# Out:
# Standard Error                  -0.177254
# Region                          -0.176791
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Observation : There is no highly negative correlated values so need of column deletion

# %% [markdown]
# # Data Preprocessing

# %%
# Split x and y

x=df.drop(columns=['Happiness Score'],axis=1)
x
# Out:
#      Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0         9         0.03411                   1.39651  1.34951
# 1         9         0.04884                   1.30232  1.40223
# 2         9         0.03328                   1.32548  1.36058
# 3         9         0.03880                   1.45900  1.33095
# 4         5         0.03553                   1.32629  1.32261
# ..      ...             ...                       ...      ...
# 153       8         0.03464                   0.22208  0.77370
# 154       8         0.03656                   0.28665  0.35386
# 155       4         0.05015                   0.66320  0.47489
# 156       8         0.08658                   0.01530  0.41587
# 157       8         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# ...

# %%
y=df['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
# # Skewness :

# %%
x.skew().sort_values(ascending=False)
# Out:
# Standard Error                   1.983439
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Region                          -0.116119
# Dystopia Residual               -0.238911
# Economy (GDP per Capita)        -0.317575
# Freedom                         -0.413462
# Health (Life Expectancy)        -0.705328
# Family                          -1.006893
# dtype: float64

# %%
# We apply Transformation to reduce skewness

# %%
#Remove Skewness - apply power transformation

from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[ 1.24453048, -0.9722262 ,  1.44606101, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [ 1.24453048,  0.30934969,  1.17332111, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [ 1.24453048, -1.06201662,  1.23983557, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [-0.30300992,  0.39913742, -0.5134688 , ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [ 0.95510156,  1.92690194, -1.89495386, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 0.95510156,  1.31032295, -1.52122584, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %%
x=pd.DataFrame(x_new,columns=x.columns)                                        #convert transformed data into DataFrame

# %%
#after transformation check skewness

x.skew().sort_values(ascending=False)
# Out:
# Trust (Government Corruption)    0.185965
# Dystopia Residual                0.022925
# Generosity                       0.013320
# Standard Error                  -0.020092
# Freedom                         -0.080728
# Economy (GDP per Capita)        -0.127233
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Region                          -0.228041
# dtype: float64

# %% [markdown]
# Observation : Skewness in range of (-0.2 to +0.1). Now We can do scaling

# %% [markdown]
# # Feature Scaling :

# %%
# Scaling increases the model performance to much extent, we get best result after scaling data

# %%
# Standard Scaling :

from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x)
x1
# Out:
# array([[ 1.24453048, -0.9722262 ,  1.44606101, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [ 1.24453048,  0.30934969,  1.17332111, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [ 1.24453048, -1.06201662,  1.23983557, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [-0.30300992,  0.39913742, -0.5134688 , ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [ 0.95510156,  1.92690194, -1.89495386, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 0.95510156,  1.31032295, -1.52122584, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %%
x=pd.DataFrame(x1,columns=x.columns)                                   #convert scaled data into DataFrame

# %%
# Multicollinearity Check VIF Technique

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)
    
vif_calc()
# Out:
#    VIF Factor                       features
# 0    1.349541                         Region
# 1    1.170792                 Standard Error
# 2    4.513021       Economy (GDP per Capita)
# 3    2.192811                         Family
# 4    4.090060       Health (Life Expectancy)
# 5    2.011668                        Freedom
# 6    1.425377  Trust (Government Corruption)
# 7    1.441925                     Generosity
# 8    1.057555              Dystopia Residual

# %% [markdown]
# * Observation : As vif value < 5 so no multicollinearity present

# %% [markdown]
# # Outliers detection :

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#        Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.244530        0.972226                  1.446061  1.669206
# 1    1.244530        0.309350                  1.173321  2.012132
# 2    1.244530        1.062017                  1.239836  1.739586
# 3    1.244530        0.503610                  1.630246  1.553118
# 4    0.030337        0.823548                  1.242168  1.501726
# ..        ...             ...                       ...       ...
# 153  0.955102        0.916014                  1.494046  0.959885
# 154  0.955102        0.719479                  1.360829  1.896644
# 155  0.303010        0.399137                  0.513469  1.690664
# 156  0.955102        1.926902                  1.894954  1.796803
# 157  0.955102        1.310323                  1.521226  2.160397
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.491765  1.756335                       1.773991
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([20, 25], dtype=int64), array([1, 1], dtype=int64))

# %%
# Removing outliers from x

df1=df[(z<3).all(axis=1)]
df1
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0         9            7.587         0.03411                   1.39651
# 1         9            7.561         0.04884                   1.30232
# 2         9            7.527         0.03328                   1.32548
# 3         9            7.522         0.03880                   1.45900
# 4         5            7.427         0.03553                   1.32629
# ..      ...              ...             ...                       ...
# 153       8            3.465         0.03464                   0.22208
# 154       8            3.340         0.03656                   0.28665
# 155       4            3.006         0.05015                   0.66320
# 156       8            2.905         0.08658                   0.01530
# 157       8            2.839         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
#After outliers removal some rows are removed so check data loss :-

# %%
# % Data Loss

data_loss=(158-156)/158*100
print(data_loss)
# Out:
# 1.2658227848101267

# %% [markdown]
# * As our data loss is acceptable so we proceed

# %% [markdown]
# # Train and Test Splitting :

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=3)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((158, 9), (110, 9), (48, 9))

# %% [markdown]
# # Modelling :

# %% [markdown]
# Metrics imported :

# %%
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# 1. LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)                                                          #fitting the data will train your model
# Out:
# LinearRegression()

# %% [markdown]
# Our Model is successfully trained , Lets perform prediction

# %%
pred_train_lr=lr.predict(x_train)
predlr=lr.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_lr))
print('Testing Accuracy is',r2_score(y_test,predlr))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predlr))
print('Mean squared Error:',mean_squared_error(y_test,predlr))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# Training Accuracy is 0.9915371061355478
# Testing Accuracy is 0.9952742623264057
# Error:
# Mean Absolute Error: 0.06659742575317613
# Mean squared Error: 0.006596303641502967
# Root Mean squared Error: 0.08121763134629677

# %%
from sklearn.model_selection import cross_val_score
cr_1=cross_val_score(lr,x,y,cv=6)
print("Cross Validation Score of Linear Regression model:-",cr_1.mean())
diff_1=r2_score(y_test,predlr)-cr_1.mean()
print("diff between r2 score and cross validation score is -",diff_1)
# Out:
# Cross Validation Score of Linear Regression model:- 0.6973952457196341
# diff between r2 score and cross validation score is - 0.29787901660677163

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge                 #Alpha Value should be same for all regression

# %% [markdown]
# 2. Lasso Regression

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)                                     #Fitting Training Model
ls_score_training=ls.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 99.15370524345921

# %%
pred_train_ls=ls.predict(x_train)
predls=ls.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_ls))
print('Testing Accuracy is',r2_score(y_test,predls))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predls))
print('Mean squared Error:',mean_squared_error(y_test,predls))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# Training Accuracy is 0.9915370524345921
# Testing Accuracy is 0.9952811778580528
# Error:
# Mean Absolute Error: 0.06652259022165422
# Mean squared Error: 0.0065866507682929365
# Root Mean squared Error: 0.08115818361873889

# %%
from sklearn.model_selection import cross_val_score
cr_2=cross_val_score(ls,x,y,cv=6)
print("Cross Validation Score of Lasso model:-",cr_2.mean())
diff_2=r2_score(y_test,predls)-cr_1.mean()
print("diff between r2 score and cross validation score is -",diff_2)
# Out:
# Cross Validation Score of Lasso model:- 0.6976977829726891
# diff between r2 score and cross validation score is - 0.29788593213841874

# %% [markdown]
# 3. Ridge Regression

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)                                     #Fitting Training Model
rd_score_training=rd.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 99.15370524345921

# %%
pred_train_rd=rd.predict(x_train)
predrd=rd.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rd))
print('Testing Accuracy is',r2_score(y_test,predrd))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrd))
print('Mean squared Error:',mean_squared_error(y_test,predrd))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# Training Accuracy is 0.9915371061351891
# Testing Accuracy is 0.9952742593124283
# Error:
# Mean Absolute Error: 0.06659737420085222
# Mean squared Error: 0.0065963078484884766
# Root Mean squared Error: 0.08121765724575215

# %%
cr_3=cross_val_score(rd,x,y,cv=6)
print("Cross Validation Score of Ridge model:-",cr_3.mean())
diff_3=r2_score(y_test,predrd)-cr_3.mean()
print("diff between r2 score and cross validation score is -",diff_3)
# Out:
# Cross Validation Score of Ridge model:- 0.6973962417863087
# diff between r2 score and cross validation score is - 0.29787801752611964

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# To make our model more perfect we try another method 4) RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_train_rf=rf.predict(x_train)
predrf=rf.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rf))
print('Testing Accuracy is',r2_score(y_test,predrf))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrf))
print('Mean squared Error:',mean_squared_error(y_test,predrf))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# Training Accuracy is 0.9795631949429298
# Testing Accuracy is 0.9196985367068758
# Error:
# Mean Absolute Error: 0.2645520833333336
# Mean squared Error: 0.1120868045000003
# Root Mean squared Error: 0.33479367452208575

# %%
cr_4=cross_val_score(rf,x,y,cv=6)
print("Cross Validation Score of Random Forest Regressor model:-",cr_4.mean())
diff_4=r2_score(y_test,predrf)-cr_4.mean()
print("diff between r2 score and cross validation score is -",diff_4)
# Out:
# Cross Validation Score of Random Forest Regressor model:- -3.8681157098957732
# diff between r2 score and cross validation score is - 4.787814246602649

# %%
result = pd.DataFrame({'Models':['Lr','ls','rd','rf'],
                       'r2_score':[r2_score(y_test,predlr)*100,
                                   r2_score(y_test,predls)*100,
                                   r2_score(y_test,predrd)*100,
                                   r2_score(y_test,predrf)*100],
                     'Difference of r2_score and cross-val':[diff_1,diff_2,diff_3,diff_4]})
result
# Out:
#   Models   r2_score  Difference of r2_score and cross-val
# 0     Lr  99.527426                              0.297879
# 1     ls  99.528118                              0.297886
# 2     rd  99.527426                              0.297878
# 3     rf  91.969854                              4.787814

# %% [markdown]
# # Save Model

# %% [markdown]
# We are saving Ridge regression model as our best model

# %%
import joblib

joblib.dump(rd,'Worldhappiness_score_prediction')
# Out:
# ['Worldhappiness_score_prediction']

# %% [markdown]
# # Load Model

# %%
model=joblib.load('Worldhappiness_score_prediction')

# %% [markdown]
# # Prediction Model

# %%
input_data=(6,0.03553,1.32629,1.32261,0.90563,0.63297,0.32957,0.45811,2.45176)

# Changing data into numpy array
input_data_nparray=np.asarray(input_data)

# reshaping data as we are predicting label for only one instance
input_data_reshaped=input_data_nparray.reshape(1,-1)

prediction=model.predict(input_data_reshaped)
print(prediction)
# Out:
# [7.71853059]

# %% [markdown]
# Hence Happiness Score Predicted
