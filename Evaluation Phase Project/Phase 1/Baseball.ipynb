# %% [markdown]
# # Importing Required Libraries :

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset :

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Checking No of Rows and columns :

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# It has 30 rows and 17 columns

# %%
# First 5 rows of dataset :
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Last 5 rows of dataset :
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# Checking columns name:

df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Checking datatypes of all columns :

df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# As per problem statement Target variable i.e. W is int64 i.e. continuous value so we Regression to learn our model. ERA is a float type data and except ERA all columns are int type data.

# %%
# Checking Missing values in dataset :

df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing values so it is good , otherwise we have to treat missing values

# %% [markdown]
# Heatmap of Null Values

# %%
#Checking for null values in heat map
plt.figure(figsize=[8,5])
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# I can see in graph that there is no null values in the given dataset.

# %%
#Checking unique values of each columns

df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# So, I can see these are number of unique values in each column.

# %%
#Checking value counts of target column

df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# I can see there are no missing values or spaaces in the target column.

# %% [markdown]
# # Data Analysis and Visulization

# %% [markdown]
# Statistical measure of dataset :

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# All statistical data of all rows shown for each parameters like mean, minimum, maximum , 25th percentile means how much value for each column are below 25th percentile ,similarly for 50th perecntile and 75th perecntile.

# %% [markdown]
# # EDA

# %%
#Univariate Analysis

# As data is continuous or integer so we draw density plot

# %%
# Runs Scored Density Plot :

sns.distplot(df['R'])
# Out:
# <Axes: xlabel='R', ylabel='Density'>

# %%
# At bat or time at bat Density Plot :

sns.distplot(df['AB'])
# Out:
# <Axes: xlabel='AB', ylabel='Density'>

# %%
# Hit Density Plot :

sns.distplot(df['H'])
# Out:
# <Axes: xlabel='H', ylabel='Density'>

# %%
# act of a batter striking  Density Plot :

sns.distplot(df['2B'])
# Out:
# <Axes: xlabel='2B', ylabel='Density'>

# %%
# Triple Density Plot :

sns.distplot(df['3B'])
# Out:
# <Axes: xlabel='3B', ylabel='Density'>

# %%
# Home Runs Density Plot :

sns.distplot(df['HR'])
# Out:
# <Axes: xlabel='HR', ylabel='Density'>

# %%
# Base on balls  Density Plot :

sns.distplot(df['BB'])
# Out:
# <Axes: xlabel='BB', ylabel='Density'>

# %%
# Strikeout Density Plot :

sns.distplot(df['SO'])
# Out:
# <Axes: xlabel='SO', ylabel='Density'>

# %%
#Stolen base Density Plot :

sns.distplot(df['SB'])
# Out:
# <Axes: xlabel='SB', ylabel='Density'>

# %%
#Run Average Density Plot :

sns.distplot(df['RA'])
# Out:
# <Axes: xlabel='RA', ylabel='Density'>

# %%
#Earned run Density Plot :

sns.distplot(df['ER'])
# Out:
# <Axes: xlabel='ER', ylabel='Density'>

# %%
#Earned Run Average Density Plot :

sns.distplot(df['ERA'])
# Out:
# <Axes: xlabel='ERA', ylabel='Density'>

# %%
#Complete Game Density Plot :

sns.distplot(df['CG'])
# Out:
# <Axes: xlabel='CG', ylabel='Density'>

# %%
#Shutout Density Plot :

sns.distplot(df['SHO'])
# Out:
# <Axes: xlabel='SHO', ylabel='Density'>

# %%
#Save Density Plot :

sns.distplot(df['SV'])
# Out:
# <Axes: xlabel='SV', ylabel='Density'>

# %%
#Errors Density Plot :

sns.distplot(df['E'])
# Out:
# <Axes: xlabel='E', ylabel='Density'>

# %% [markdown]
# * OBSERVATION : Almost all the columns are normally distributed.Except R,SO,CG and E.

# %%
#Bivariate Analysis

## SCATTER PLOT

# %%
plt.scatter(df['R'],df['W'])

# %% [markdown]
# * Observation : Max. Values of R lies in range of 640-750

# %%
plt.scatter(df['AB'],df['W'])

# %% [markdown]
# * Observation : Max. Values of AB lies in range of 5450-5550

# %%
plt.scatter(df['H'],df['W'])

# %% [markdown]
# * Observation : Max. Values of H lies in range of 1350-1375

# %%
plt.scatter(df['2B'],df['W'])

# %% [markdown]
# * Observation : Max. Values of 2B lies in range of 260-300

# %%
plt.scatter(df['3B'],df['W'])

# %% [markdown]
# * Observation : Max. Values of 3B lies in range of 20-40

# %%
plt.scatter(df['HR'],df['W'])

# %% [markdown]
# * Observation : Max. Values of HR lies in range of 140-180

# %%
plt.scatter(df['BB'],df['W'])

# %% [markdown]
# * Observation : Max. Values of BB lies in range of 400-475

# %%
plt.scatter(df['SO'],df['W'])

# %% [markdown]
# * Observation : Max. Values of SO lies in range of 1100-1300

# %%
plt.scatter(df['SB'],df['W'])

# %% [markdown]
# * Observation : Max. Values of SB lies in range of 70-90

# %%
plt.scatter(df['RA'],df['W'])

# %% [markdown]
# * Observation : Max. Values of RA lies in range of 675-750

# %%
plt.scatter(df['ER'],df['W'])

# %% [markdown]
# * Observation : Max. Values of ER lies in range of 625-700

# %%
plt.scatter(df['ERA'],df['W'])

# %% [markdown]
# * Observation : Max. Values of ERA lies in range of 4-4.5

# %%
plt.scatter(df['CG'],df['W'])

# %% [markdown]
# * Observation : Max. Values of CG lies in range of 1-3

# %%
plt.scatter(df['SHO'],df['W'])

# %% [markdown]
# * Observation : Max. Values of SHO lies in range of 10-12.5

# %%
plt.scatter(df['SV'],df['W'])

# %% [markdown]
# * Observation : Max. Values of Save lies in range of 35-50

# %%
plt.scatter(df['E'],df['W'])

# %% [markdown]
# * Observation : Max. Values of error lies in range of 85-95

# %% [markdown]
# As, we can see in plot SV,ERA,SHO and R is having almost linear relationship with target variable and other variables are having non linear relation ship with target variable.

# %%
## Multivariate Analysis

# %%
df.plot(kind='density',subplots=True,layout=(4,5),sharex=False,legend=True,figsize=(18,10))
plt.show()

# %%
#Observation : As datas are not perfectly well shaped curved,so have to remove skewness

# %% [markdown]
# # Correlation :

# %%
#Now we check correlation of input parameters with output "quality" :
#positively correlated : direct correlation
#negatively correlated : negative correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# For better understanding of correlation matrix between columns we draw heatmap :

plt.figure(figsize=(10,5))
sns.heatmap(dfcor,annot=True)
# Out:
# <Axes: >

# %%
# We can change color also and decimal values place :

plt.figure(figsize=(12,6))
sns.heatmap(dfcor,annot=True,cmap='Blues',fmt='0.2f',cbar=True,square=False)
# Out:
# <Axes: >

# %% [markdown]
# In this chart it is showing. it is lightly correlated with each other but RA,ER,ERA columns are highly correlated with each other. Also These columns are highly negatively correlated with Wins(W) columns that means there is high impact of these columns on wining. We are dropping two columns(er,ra) and keeping ERA from them because these have same kind of effect on wins, will not affect the prediction model.

# %%
plt.figure(figsize =(25, 10))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind ='bar', color ='skyblue')
plt.xlabel('Features')
plt.ylabel('Column with target names')
plt.title('Correlation')
plt.show()

# %% [markdown]
# As we can see from the correlation matrix and the graph,ER,RA,ERA have the strongest correlation with wins but in negative nature.
#
# In positive side SV has the highest correlation of 0.67 followed by BB,SHO,R,2B all above 0.4.
#
# Even though ER,RA and ERA are very negatively correlated with wins but they showed highest correlation amongst themselves of over 0.8.

# %%
df1=df.drop(["ER","RA"],axis=1)
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88  3.80   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# ...

# %% [markdown]
# # Outliers Detection and Removal:

# %%
df1.plot(kind='box',fontsize=10,figsize=(10,10),color='g')
# Out:
# <Axes: >

# %% [markdown]
# By observing the box plot i can say that there are outliers are R-Runs,ERA-Earned Run average,SHO-Shutout,SV-Saves,E-Errors.

# %% [markdown]
# REMOVING OUTLIERS :

# %%
# Zscore method:

#Features having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df1[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 6    87  764  5567  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121  3.57   5   13  39   85
# ...

# %% [markdown]
# So,I have removed outliers by using Zscore.

# %%
#Checking shape of new dataset

df_new.shape
# Out:
# (29, 15)

# %% [markdown]
# There are 29 rows and 15 columns of shape of new dataset after removing outliers.

# %%
#Checking shape of old dataset
df1.shape
# Out:
# (30, 15)

# %% [markdown]
# There were 30 rows and 15 columns in old dataset.

# %%
# % Data Loss

data_loss=(30-29)/30*100
print(data_loss)
# Out:
# 3.3333333333333335

# %% [markdown]
# So, I can see dataloss in zscore method after removing outliers of 3.33% which is less than 10%. So we check Skewness now.

# %% [markdown]
# # Data Preprocessing :

# %% [markdown]
# Splitting the columns :

# %%
x=df_new.iloc[:,1:-1]
y=df_new.iloc[:,0]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV
# 0   724  5575  1497  300  42  139  383   973  104  3.73   2    8  56
# 1   696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45
# 2   669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38
# 3   622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37
# 4   689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35
# 6   764  5567  1397  272  19  212  554  1227   63  4.03   3    4  48
# 7   713  5485  1370  246  20  217  418  1331   44  4.05   0   10  43
# 8   644  5485  1383  278  32  167  436  1310   87  3.74   1   12  60
# 9   748  5640  1495  294  33  161  478  1148   71  4.31   3   10  40
# 10  751  5511  1419  279  32  172  503  1233  101  4.24   5    9  45
# 11  729  5459  1363  278  26  230  486  1392  121  3.57   5   13  39
# 12  661  5417  1331  243  21  176  435  1150   52  3.94   2   12  46
# 13  656  5544  1379  262  22  198  478  1336   69  4.16   6   12  45
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Checking for Skewness:

# %%
#Checking for Skewness

x.skew().sort_values(ascending=False)
# Out:
# CG     0.854980
# H      0.783772
# SV     0.627480
# SHO    0.526943
# SB     0.494966
# HR     0.450862
# AB     0.169573
# BB     0.151193
# 3B     0.090124
# ERA    0.016693
# R     -0.215364
# SO    -0.233815
# 2B    -0.335304
# dtype: float64

# %% [markdown]
# I can see that there is skewness in Hits(H),Completed games(CG),Shoutouts(SHO),Saves(SV),Errors(E).

# %% [markdown]
# # Removing Skewness:

# %%
#Remove Skewness - apply power transformation

from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[ 9.62543504e-01,  8.38257983e-01,  4.16333634e-16,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.98863300e-01, -6.92877447e-01, -2.49800181e-16,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [-3.12105130e-01, -1.11045984e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
#        [-1.30829774e+00,  2.59829043e-01, -8.32667268e-17,
#         -8.37664770e-01, -4.32227907e-01, -8.60039342e-01,
#         -1.16272085e+00, -2.30682707e-01, -6.18421529e-01,
# ...

# %%
x=pd.DataFrame(x_new,columns=x.columns)                                        #convert transformed data into DataFrame

# %%
#after transformation check skewness

x.skew().sort_values(ascending=False)
# Out:
# AB     0.081092
# SO     0.051530
# SHO    0.000529
# HR     0.000448
# H      0.000000
# ERA   -0.000401
# SV    -0.000925
# BB    -0.008572
# SB    -0.009570
# R     -0.024842
# CG    -0.045947
# 2B    -0.052793
# 3B    -0.075139
# dtype: float64

# %% [markdown]
# After trying to remove skewness using yeo-johnson method i got 0.0 skewness.

# %% [markdown]
# # Feature Scaling :

# %%
# Scaling increases the model performance to much extent, we get best result after scaling data

# Standard Scaling :

from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x)
x1
# Out:
# array([[ 9.62543504e-01,  8.39431267e-01,  1.65963137e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.98863300e-01, -6.91704164e-01, -9.59650790e-01,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [-3.12105130e-01, -1.10928655e+00,  2.25800186e-02,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
#        [-1.30829774e+00,  2.61002327e-01, -3.04830251e-01,
#         -8.37664770e-01, -4.32227907e-01, -8.60039342e-01,
#         -1.16272085e+00, -2.30682707e-01, -6.18421529e-01,
# ...

# %%
x=pd.DataFrame(x1,columns=x.columns)                                   #convert scaled data into DataFrame

# %%
# Multicollinearity Check VIF Technique

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)
    
vif_calc()
# Out:
#     VIF Factor features
# 0     4.789044        R
# 1     3.362368       AB
# 2     5.544096        H
# 3     3.069725       2B
# 4     2.895396       3B
# 5     4.187019       HR
# 6     2.896999       BB
# 7     2.113640       SO
# 8     1.945339       SB
# 9     4.507646      ERA
# 10    2.218300       CG
# 11    3.080069      SHO
# 12    2.266880       SV

# %% [markdown]
# Observation : As vif value < 10 so no multicollinearity present.

# %% [markdown]
# # Train and Test Splitting :

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
## Let find the best random state:

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9715759643862034
# At random state0, The test accuracy is :-0.5137968811522993
#
#
# At random state1, The training accuracy is :-0.9552424480325186
# At random state1, The test accuracy is :-0.7802369056575222
#
#
# At random state2, The training accuracy is :-0.9489276771646376
# At random state2, The test accuracy is :-0.00032951971580830186
#
#
# At random state3, The training accuracy is :-0.9422079493836518
# At random state3, The test accuracy is :-0.8595447615091449
#
#
# At random state4, The training accuracy is :-0.9544073450852989
# At random state4, The test accuracy is :-0.7778811972595882
#
#
# At random state5, The training accuracy is :-0.9572406833293825
# At random state5, The test accuracy is :-0.5447053570456184
#
#
# At random state6, The training accuracy is :-0.9263317019876227
# At random state6, The test accuracy is :-0.9705862065378078
#
#
# At random state7, The training accuracy is :-0.9540665337793217
# ...

# %% [markdown]
# I can see random state=47 giving highest accuracy,choosing that as random state.

# %%
#Splitting the data into 80% training and 20% testing

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=47)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((29, 13), (23, 13), (6, 13))

# %% [markdown]
# # Model Building:

# %% [markdown]
# Regression Algorithms:

# %% [markdown]
# 1. LINEAR REGRESSION :

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)                                                          #fitting the data will train your model)
# Out:
# LinearRegression()

# %% [markdown]
# Our Model is successfully trained , Lets perform prediction

# %%
pred_train_lr=lr.predict(x_train)
predlr=lr.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_lr))
print('Testing Accuracy is',r2_score(y_test,predlr))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predlr))
print('Mean squared Error:',mean_squared_error(y_test,predlr))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# Training Accuracy is 0.9269394422360882
# Testing Accuracy is 0.985663938561681
# Error:
# Mean Absolute Error: 1.2881076394367479
# Mean squared Error: 1.809529532658937
# Root Mean squared Error: 1.345187545533684

# %%
from sklearn.model_selection import cross_val_score
cr_1=cross_val_score(lr,x,y,cv=8)
print("Cross Validation Score of Linear Regression model:-",cr_1.mean())
diff_1=r2_score(y_test,predlr)-cr_1.mean()
print("diff between r2 score and cross validation score is -",diff_1)
# Out:
# Cross Validation Score of Linear Regression model:- 0.4807912847401985
# diff between r2 score and cross validation score is - 0.5048726538214825

# %% [markdown]
# 2) SGD:

# %%
from sklearn.linear_model import SGDRegressor

sgd=SGDRegressor()
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor()

# %% [markdown]
# Our Model is successfully trained , Lets perform prediction

# %%
pred_train_sgd=sgd.predict(x_train)
predsgd=sgd.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_sgd))
print('Testing Accuracy is',r2_score(y_test,predsgd))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predsgd))
print('Mean squared Error:',mean_squared_error(y_test,predsgd))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predsgd)))
# Out:
# Training Accuracy is 0.9184808561836675
# Testing Accuracy is 0.9176812162364337
# Error:
# Mean Absolute Error: 2.695173984202968
# Mean squared Error: 10.390459817267926
# Root Mean squared Error: 3.2234236174086592

# %%
from sklearn.model_selection import cross_val_score
cr_2=cross_val_score(sgd,x,y,cv=8)
print("Cross Validation Score of SGD Regression model:-",cr_2.mean())
diff_2=r2_score(y_test,predsgd)-cr_2.mean()
print("diff between r2 score and cross validation score is -",diff_2)
# Out:
# Cross Validation Score of SGD Regression model:- 0.40732879359144253
# diff between r2 score and cross validation score is - 0.5103524226449911

# %% [markdown]
# # Regularization :

# %%
from sklearn.linear_model import Lasso,Ridge                 #Alpha Value should be same for all regression

# %% [markdown]
# 3. Lasso Regression :

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)                                     #Fitting Training Model
ls_score_training=ls.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 92.69394245997509

# %%
pred_train_ls=ls.predict(x_train)
predls=ls.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_ls))
print('Testing Accuracy is',r2_score(y_test,predls))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predls))
print('Mean squared Error:',mean_squared_error(y_test,predls))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# Training Accuracy is 0.9269394245997509
# Testing Accuracy is 0.9856711539180592
# Error:
# Mean Absolute Error: 1.2874761545089228
# Mean squared Error: 1.8086187943427519
# Root Mean squared Error: 1.3448489857016481

# %%
from sklearn.model_selection import cross_val_score
cr_3=cross_val_score(ls,x,y,cv=8)
print("Cross Validation Score of Lasso model:-",cr_3.mean())
diff_3=r2_score(y_test,predls)-cr_3.mean()
print("diff between r2 score and cross validation score is -",diff_3)
# Out:
# Cross Validation Score of Lasso model:- 0.4809500492134916
# diff between r2 score and cross validation score is - 0.5047211047045675

# %% [markdown]
# 4. Ridge Regression :

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)                                     #Fitting Training Model
rd_score_training=rd.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 92.69394245997509

# %%
pred_train_rd=rd.predict(x_train)
predrd=rd.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rd))
print('Testing Accuracy is',r2_score(y_test,predrd))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrd))
print('Mean squared Error:',mean_squared_error(y_test,predrd))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# Training Accuracy is 0.9269394419984635
# Testing Accuracy is 0.9856640843178757
# Error:
# Mean Absolute Error: 1.2880581112144067
# Mean squared Error: 1.8095111349881314
# Root Mean squared Error: 1.3451807071870052

# %%
cr_4=cross_val_score(rd,x,y,cv=8)
print("Cross Validation Score of Ridge model:-",cr_4.mean())
diff_4=r2_score(y_test,predrd)-cr_4.mean()
print("diff between r2 score and cross validation score is -",diff_4)
# Out:
# Cross Validation Score of Ridge model:- 0.4807980621605946
# diff between r2 score and cross validation score is - 0.504866022157281

# %% [markdown]
# # Ensemble Technique :

# %% [markdown]
# To make our model more perfect we try another method
#
# 5) RandomForestRegressor :

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_train_rf=rf.predict(x_train)
predrf=rf.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rf))
print('Testing Accuracy is',r2_score(y_test,predrf))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrf))
print('Mean squared Error:',mean_squared_error(y_test,predrf))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# Training Accuracy is 0.9351397689513947
# Testing Accuracy is 0.6858190580985914
# Error:
# Mean Absolute Error: 5.675000000000002
# Mean squared Error: 39.656616666666686
# Root Mean squared Error: 6.297349971747376

# %%
cr_5=cross_val_score(rf,x,y,cv=8)
print("Cross Validation Score of Random Forest Regressor model:-",cr_5.mean())
diff_5=r2_score(y_test,predrf)-cr_5.mean()
print("diff between r2 score and cross validation score is -",diff_5)
# Out:
# Cross Validation Score of Random Forest Regressor model:- -0.10137767606442949
# diff between r2 score and cross validation score is - 0.7871967341630209

# %%
result = pd.DataFrame({'Models':['Lr','sgd','ls','rd','rf'],
                       'r2_score':[r2_score(y_test,predlr)*100,
                                   r2_score(y_test,predsgd)*100,
                                   r2_score(y_test,predls)*100,
                                   r2_score(y_test,predrd)*100,
                                   r2_score(y_test,predrf)*100],
                     'Difference of r2_score and cross-val':[diff_1,diff_2,diff_3,diff_4,diff_5]})
result
# Out:
#   Models   r2_score  Difference of r2_score and cross-val
# 0     Lr  98.566394                              0.504873
# 1    sgd  91.768122                              0.510352
# 2     ls  98.567115                              0.504721
# 3     rd  98.566408                              0.504866
# 4     rf  68.581906                              0.787197

# %% [markdown]
# According to all metrics score selecting the lassoRegression as final model

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.001,0.01,0.1,1.0],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000]}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=8)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=8, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GVC.best_params_
# Out:
# {'alpha': 0.1, 'max_iter': 8, 'selection': 'random', 'tol': 1000}

# %% [markdown]
# I can see best parameters.

# %%
Final_mod=Lasso(alpha=0.1, max_iter=8, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('Training Accuracy is',r2_score(y_train,pred_train_ls))
print('Testing Accuracy is',r2_score(y_test,predls))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predls))
print('Mean squared Error:',mean_squared_error(y_test,predls))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# Training Accuracy is 0.9269394245997509
# Testing Accuracy is 0.9856711539180592
# Error:
# Mean Absolute Error: 1.2874761545089228
# Mean squared Error: 1.8086187943427519
# Root Mean squared Error: 1.3448489857016481

# %% [markdown]
# After tuning,  We are getting Testing Accuracy is 0.9856711539180592 which is very good.

# %% [markdown]
# # Saving the model:

# %% [markdown]
# We are saving Lasso regression model as our best model

# %%
import joblib

joblib.dump(ls,'Baseball_case_study')
# Out:
# ['Baseball_case_study']

# %% [markdown]
# # Load Model

# %%
model=joblib.load('Baseball_case_study')

# %% [markdown]
# # Prediction Model

# %%
#Prediction
prediction = ls.predict(x_test)
prediction
# Out:
# array([98.51387024, 77.00764781, 74.78421764, 87.01800675, 77.93569514,
#        62.50684018])

# %% [markdown]
# These are predicted values

# %%
conclusion=pd.DataFrame([ls.predict(x_test)[:],predls[:]],index=["Predicted","Original"])
conclusion
# Out:
#                   0          1          2          3          4         5
# Predicted  98.51387  77.007648  74.784218  87.018007  77.935695  62.50684
# Original   98.51387  77.007648  74.784218  87.018007  77.935695  62.50684

# %% [markdown]
# Both original and predicted values are exactly equal so model is predicted well .

# %% [markdown]
# # COMPLETED THE BASEBALLCASE STUDY
