# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOADING DataSet

# %%
df=pd.read_csv("student_grade.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119 ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203  \
# ...

# %%
# Top 5 Rows :

df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
#Last 5 Rows

df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
# Checking Data types :

df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [markdown]
# All Datatypes are correct and independent variables need to be encoded

# %%
# Checking Column names :

df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
# Checking Target Variable

df['CGPA'].unique()
# Out:
# array([2.205, 2.008, 3.608, 1.906, 3.448, 3.026, 2.957, 3.043, 3.358,
#        3.247, 2.681, 3.281, 2.792, 3.523, 3.443, 2.777, 3.248, 1.787,
#        3.572, 3.483, 2.246, 2.956, 2.953, 3.586, 3.475, 2.228, 3.44 ,
#        2.188, 3.195, 2.294, 3.133, 3.22 , 3.112, 3.16 , 3.019, 3.164,
#        3.332, 2.165, 3.7  , 3.033, 2.696, 2.851, 3.058, 1.493, 2.069,
#        1.996, 3.897, 3.848, 3.404, 2.254, 2.655, 3.106, 2.793, 3.023,
#        3.01 , 3.4  , 1.899, 3.168, 2.57 , 2.418, 2.564, 2.468, 3.769,
#        2.999, 2.768, 2.822, 3.189, 2.715, 3.578, 3.49 , 2.805, 3.458,
#        2.34 , 3.252, 2.683, 3.378, 3.295, 3.193, 3.647, 2.815, 2.171,
#        3.761, 2.763, 2.938, 2.06 , 1.261, 2.378, 2.861, 2.363, 2.084,
#        1.38 , 1.89 , 3.861, 1.805, 3.925, 3.919, 3.258, 3.963, 2.396,
#        3.772, 1.768, 3.176, 3.335, 3.758, 3.208, 1.845, 3.946, 2.3  ,
#        3.759, 3.516, 2.087, 3.137, 2.011, 2.566, 1.993, 3.334, 2.056,
# ...

# %% [markdown]
# * Observation Target Variable shows this is Regression Problem

# %% [markdown]
# # Data Vizualization

# %%
# Checking Null Values


df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# * Many null values are present .Treating Null Values as all are categorical data so simpleimputer technique applied

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="most_frequent")
df['CY-105']=imp.fit_transform(df['CY-105'].values.reshape(-1,1))
df['HS-105/12']=imp.fit_transform(df['HS-105/12'].values.reshape(-1,1))
df['MT-111']=imp.fit_transform(df['MT-111'].values.reshape(-1,1))
df['CS-106']=imp.fit_transform(df['CS-106'].values.reshape(-1,1))
df['EL-102']=imp.fit_transform(df['EL-102'].values.reshape(-1,1))
df['EE-119']=imp.fit_transform(df['EE-119'].values.reshape(-1,1))
df['ME-107']=imp.fit_transform(df['ME-107'].values.reshape(-1,1))
df['CS-107']=imp.fit_transform(df['CS-107'].values.reshape(-1,1))
df['HS-205/20']=imp.fit_transform(df['HS-205/20'].values.reshape(-1,1))
df['MT-222']=imp.fit_transform(df['MT-222'].values.reshape(-1,1))
df['EE-222']=imp.fit_transform(df['EE-222'].values.reshape(-1,1))
df['MT-224']=imp.fit_transform(df['MT-224'].values.reshape(-1,1))
df['CS-210']=imp.fit_transform(df['CS-210'].values.reshape(-1,1))
df['CS-211']=imp.fit_transform(df['CS-211'].values.reshape(-1,1))
df['CS-203']=imp.fit_transform(df['CS-203'].values.reshape(-1,1))
df['CS-214']=imp.fit_transform(df['CS-214'].values.reshape(-1,1))
df['EE-217']=imp.fit_transform(df['EE-217'].values.reshape(-1,1))
df['CS-212']=imp.fit_transform(df['CS-212'].values.reshape(-1,1))
df['CS-215']=imp.fit_transform(df['CS-215'].values.reshape(-1,1))
df['MT-331']=imp.fit_transform(df['MT-331'].values.reshape(-1,1))
df['EF-303']=imp.fit_transform(df['EF-303'].values.reshape(-1,1))
df['HS-304']=imp.fit_transform(df['HS-304'].values.reshape(-1,1))
df['CS-301']=imp.fit_transform(df['CS-301'].values.reshape(-1,1))
df['CS-302']=imp.fit_transform(df['CS-302'].values.reshape(-1,1))
df['TC-383']=imp.fit_transform(df['TC-383'].values.reshape(-1,1))
df['MT-442']=imp.fit_transform(df['MT-442'].values.reshape(-1,1))
df['EL-332']=imp.fit_transform(df['EL-332'].values.reshape(-1,1))
df['CS-318']=imp.fit_transform(df['CS-318'].values.reshape(-1,1))
df['CS-306']=imp.fit_transform(df['CS-306'].values.reshape(-1,1))
df['CS-312']=imp.fit_transform(df['CS-312'].values.reshape(-1,1))
df['CS-317']=imp.fit_transform(df['CS-317'].values.reshape(-1,1))
df['CS-403']=imp.fit_transform(df['CS-403'].values.reshape(-1,1))
df['CS-421']=imp.fit_transform(df['CS-421'].values.reshape(-1,1))
df['CS-406']=imp.fit_transform(df['CS-406'].values.reshape(-1,1))
df['CS-414']=imp.fit_transform(df['CS-414'].values.reshape(-1,1))
df['CS-419']=imp.fit_transform(df['CS-419'].values.reshape(-1,1))
df['CS-423']=imp.fit_transform(df['CS-423'].values.reshape(-1,1))
df['CS-412']=imp.fit_transform(df['CS-412'].values.reshape(-1,1))

# %%
# Checking again nulll values :

df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# Now no null values there so we can proceed

# %%
# Heatmap of Null Values

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# As we know
#
# Seat No is Ordinal Data (have some relation/sequence) -> Categorical Data
#
# other all independent variable are Nominal Data(No Relation between Data) -> Categorical Data
#
# CGPA is Target Variable which is continuous value .

# %%
#Making DataFrame for Nominal Data

# %%
df_visualization_nominal=df.iloc[:,1:-1].copy()
df_visualization_nominal.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %% [markdown]
# Visualization of Nominal Data
#
# For Nominal categorical Data we will use countplot as it will give the frequency of the classes of the columns
#
# Visualization of Ordinal Data
#
# For Ordinal Categorical Data we will use lineplot as it will give the flow of the line of the classes of the columns

# %%
df=df.drop(["Seat No."],axis=1)
df                                                                       #As Seat No. we can drop
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %% [markdown]
# # EDA :

# %% [markdown]
# Visualization for Nominal Data - CountPlot

# %%
# 'PH-121' Countplot :

ax=sns.countplot(x='PH-121',data=df_visualization_nominal)

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 111,Total No of Grade C+ is 31 and so on

# %%
# 'HS-105/12' Countplot :

ax=sns.countplot(x='HS-105/12',data=df_visualization_nominal)

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 97,Total No of Grade B is 57 ,Total No of Grade WU is 2 ,Total No of Grade F is 1 and so on

# %%
# 'EE-119' countplot :

ax=sns.countplot(x='EE-119',data=df_visualization_nominal)

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 139,Total No of Grade B is 77 ,Total No of Grade WU is 1,Total No of Grade D+ is 26 and so on

# %%
# 'CS-211' countplot :

ax=sns.countplot(x='CS-211',data=df_visualization_nominal)

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
# 'HS-304' countplot :

ax=sns.countplot(x='HS-304',data=df_visualization_nominal)

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %% [markdown]
# Since we have plotted count graph for most of columns but there are 41 Nominal Data present so it will be very time consuming to draw for each column

# %% [markdown]
# * Now check Distribution of Continuous value of float type columns

# %%
df_visualization_continuous=df[['CGPA']].copy()                               #created Dataframe for continuous value
sns.displot(df_visualization_continuous['CGPA'],kde=True)

# %% [markdown]
# * Observation : Data is highly left skewed

# %% [markdown]
# # Encoding Categorical columns

# %% [markdown]
# As our data has lot of string/object values so convert in numerical data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ME-107  CS-107  HS-205/20  MT-222  EE-222  MT-224  \
# ...

# %% [markdown]
# All Data converted in Numerical values

# %%
# Statistical Summary

df.describe().T                                                     #Taken Transpose so can see all columns summary
# Out:
#            count        mean         std  min      25%      50%      75%  \
# Seat No.   571.0  285.000000  164.977776  0.0  142.500  285.000  427.500
# PH-121     571.0    3.781086    3.046895  0.0    2.000    3.000    6.000
# HS-101     571.0    5.071804    2.785317  0.0    3.000    5.000    7.000
# CY-105     571.0    2.921191    2.992228  0.0    0.000    2.000    5.000
# HS-105/12  571.0    4.264448    3.216478  0.0    2.000    4.000    7.000
# MT-111     571.0    3.935201    3.034481  0.0    2.000    4.000    6.000
# CS-105     571.0    2.838879    2.696709  0.0    0.000    2.000    4.000
# CS-106     571.0    4.161121    2.774311  0.0    2.000    4.000    6.000
# EL-102     571.0    3.998249    3.075939  0.0    2.000    4.000    6.000
# EE-119     571.0    3.921191    2.698100  0.0    2.000    3.000    6.000
# ME-107     571.0    4.817863    3.179170  0.0    2.000    5.000    8.000
# CS-107     571.0    4.117338    3.304207  0.0    1.000    4.000    7.000
# ...

# %% [markdown]
# *Observation
#
# Data is skewed for various columns and outliers also present as much diffrence in 3rd quartile and max values

# %%
## We draw distribution plot for columns as all data present in numerical form ##

## Univariate Analysis :

# %%
# 'MT-222' Distribution Plot :

sns.distplot(df['MT-222'])
# Out:
# <Axes: xlabel='MT-222', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %%
# 'HS-205/20' Distribution Plot :

sns.distplot(df['HS-205/20'])
# Out:
# <Axes: xlabel='HS-205/20', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %%
# 'EL-332' Distribution Plot :

sns.distplot(df['EL-332'])
# Out:
# <Axes: xlabel='EL-332', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %%
# 'CS-318' Distribution Plot :

sns.distplot(df['CS-318'])
# Out:
# <Axes: xlabel='CS-318', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %%
# 'CS-419' Distribution Plot :

sns.distplot(df['CS-419'])
# Out:
# <Axes: xlabel='CS-419', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %%
# 'CS-412' Distribution Plot :

sns.distplot(df['CS-412'])
# Out:
# <Axes: xlabel='CS-412', ylabel='Density'>

# %% [markdown]
# * observation : High skewness present in data . very distorted data present.

# %% [markdown]
# Since 41 columns are there so drawing plots for each and every columns taks a lot time so we skip

# %%
# BIVARIATE ANALYSIS :

# We draw scatter plot of input paramters with target variable

# %%
# MT-224 Scatter Plot :

plt.scatter(df['CGPA'],df['MT-224'])

# %% [markdown]
# * Observation : Max. Suject Values present between 5-10 for grades between 2.0-4.0

# %%
# HS-205/20 Scatter Plot :

plt.scatter(df['CGPA'],df['HS-205/20'])

# %% [markdown]
# Observation : Max. Suject Values present between 2-10 for grades between 2.0-4.0

# %%
# MT-331 Scatter Plot :

plt.scatter(df['CGPA'],df['MT-331'])

# %% [markdown]
# Observation : Max. Suject Values present between 2-10 for grades between 2.0-4.0

# %%
# EF-303 Scatter Plot :

plt.scatter(df['CGPA'],df['EF-303'])

# %% [markdown]
# Observation : Max. Suject Values present between 2-9 for grades between 2.0-4.0

# %%
# TC-383 Scatter Plot :

plt.scatter(df['CGPA'],df['TC-383'])

# %% [markdown]
# Max. Suject Values present between 2-10 for grades between 2.5-4.0

# %%
# EL-332 Scatter Plot :

plt.scatter(df['CGPA'],df['EL-332'])

# %% [markdown]
# Max. Suject Values present between 2-11 for grades between 2.5-4.0

# %%
# CS-423 Scatter Plot :

plt.scatter(df['CGPA'],df['CS-423'])

# %% [markdown]
# Max. Suject Values present between 2-11 for grades between 2.5-4.0

# %% [markdown]
# * MULTIVARIATE ANALYSIS

# %%
#check data distribution among all coulmns

df.plot(kind='density',subplots=True,layout=(6,7),sharex=False,legend=True,figsize=(18,10))
plt.show()

# %% [markdown]
# # Correlation :

# %%
#Now we check correlation of input parameters with output "quality" :
#positively correlated : direct correlation
#negatively correlated : negative correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.557843   0.498561  0.468968  0.609990
# HS-101     0.382436  1.000000  0.335074   0.473132  0.432742  0.400713
# CY-105     0.557843  0.335074  1.000000   0.510123  0.538380  0.578573
# HS-105/12  0.498561  0.473132  0.510123   1.000000  0.494731  0.482406
# MT-111     0.468968  0.432742  0.538380   0.494731  1.000000  0.393684
# CS-105     0.609990  0.400713  0.578573   0.482406  0.393684  1.000000
# CS-106     0.293963  0.312019  0.378223   0.499093  0.500729  0.286324
# EL-102     0.423942  0.349412  0.447539   0.360304  0.555895  0.353949
# EE-119     0.579964  0.309697  0.467250   0.400303  0.409161  0.507357
# ME-107     0.533558  0.336545  0.464418   0.320137  0.471685  0.455470
# CS-107     0.477761  0.495906  0.481277   0.540405  0.488977  0.503239
# HS-205/20  0.296428  0.178344  0.261281   0.179766  0.328574  0.192982
# ...

# %%
# For better understanding of correlation matrix between columns we draw heatmap :

plt.figure(figsize=(10,4))
sns.heatmap(dfcor,annot=True)
# Out:
# <Axes: >

# %%
# We can change color also and decimal values place :

plt.figure(figsize=(8,6))
sns.heatmap(dfcor,annot=True,cmap='Blues',fmt='0.2f',cbar=True,square=False)
# Out:
# <Axes: >

# %%
#Correlation of all columns with the target column 'Happiness Score':

# %%
df.corr()["CGPA"].sort_values()
# Out:
# CS-210      -0.761468
# CS-317      -0.760792
# CS-214      -0.733848
# CS-215      -0.730460
# MT-111      -0.730095
# EL-332      -0.729609
# CS-306      -0.708299
# CS-302      -0.696112
# MT-224      -0.692696
# CS-301      -0.664117
# PH-121      -0.663135
# ME-107      -0.663023
# CY-105      -0.658282
# MT-222      -0.656320
# EE-217      -0.655993
# EE-119      -0.646829
# CS-203      -0.644191
# CS-212      -0.642878
# EL-102      -0.642262
# CS-419      -0.641804
# CS-421      -0.633001
# CS-211      -0.628070
# CS-107      -0.615309
# HS-105/12   -0.613989
# CS-105      -0.613169
# MT-442      -0.582592
# EE-222      -0.575335
# TC-383      -0.572329
# CS-318      -0.566393
# HS-304      -0.557912
# CS-403      -0.544543
# HS-101      -0.537170
# CS-106      -0.534995
# CS-423      -0.520968
# MT-331      -0.508428
# EF-303      -0.485478
# CS-406      -0.474419
# CS-412      -0.466512
# HS-205/20   -0.460525
# CS-312      -0.458019
# CS-414      -0.384003
# ...

# %% [markdown]
# There are many highly negative values with target variable present but if we delete these then many columns will be deleted. So we skip
#
# Datas with -/+0.3 to 0.5 has weak correlation , Datas with -/+0.5 to 0.7 has moderate correlation and Datas with -/+0.7 to 1.0 have very strong correlation with target variable

# %% [markdown]
# # Data Preprocessing

# %%
# Split x and y

x=df.drop(columns=['CGPA'],axis=1)
x
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# ...

# %%
y=df['CGPA']
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %% [markdown]
# # Skewness :

# %%
x.skew().sort_values(ascending=False)
# Out:
# CS-406       1.522703
# CS-412       1.329362
# CS-414       1.292931
# CY-105       0.982144
# CS-105       0.930769
# HS-205/20    0.897186
# MT-442       0.869952
# EE-222       0.759105
# EE-217       0.724325
# CS-210       0.723967
# CS-106       0.639845
# MT-331       0.627721
# CS-403       0.618339
# CS-302       0.601788
# EE-119       0.574880
# PH-121       0.549104
# HS-304       0.544843
# CS-423       0.526550
# CS-419       0.506748
# EL-102       0.501161
# MT-111       0.484906
# EL-332       0.459160
# CS-312       0.442525
# MT-224       0.430480
# CS-306       0.424753
# CS-301       0.415084
# CS-212       0.414872
# CS-107       0.414846
# EF-303       0.383655
# CS-318       0.356504
# TC-383       0.331652
# HS-105/12    0.324183
# CS-203       0.274205
# MT-222       0.193993
# CS-421       0.179508
# CS-215       0.163631
# CS-317       0.140692
# CS-211       0.116085
# ME-107       0.108385
# HS-101       0.053303
# CS-214       0.013129
# ...

# %%
# We apply Transformation to reduce skewness

# %%
#Remove Skewness - apply power transformation

from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[ 0.56128983,  1.67473424,  1.41859124, ...,  1.58609347,
#         -0.1989044 , -0.30533145],
#        [-1.53065764,  1.35936594,  1.67610532, ...,  0.91653706,
#          0.78898872,  0.18007338],
#        [-1.53065764, -0.70688664, -1.27419722, ..., -1.92838387,
#         -0.60964378, -1.83058001],
#        ...,
#        [-0.04153262, -1.98470667,  0.04362548, ...,  0.16353993,
#         -0.60964378, -0.30533145],
#        [-1.53065764, -0.33373024,  1.55354794, ..., -0.25875796,
#          0.48900534,  1.247191  ],
#        [ 0.81556321,  1.35936594,  1.55354794, ...,  0.16353993,
#          1.57754608,  1.7850762 ]])

# %%
x=pd.DataFrame(x_new,columns=x.columns)                                        #convert transformed data into DataFrame

# %%
#after transformation check skewness

x.skew().sort_values(ascending=False)
# Out:
# CS-406       0.004401
# CS-412       0.004089
# CS-414      -0.005778
# CY-105      -0.013505
# HS-304      -0.034782
# CS-105      -0.036751
# CS-106      -0.039215
# CS-419      -0.044736
# MT-442      -0.045893
# HS-205/20   -0.056730
# EF-303      -0.059425
# EE-119      -0.063288
# CS-212      -0.064365
# EE-222      -0.069595
# CS-302      -0.069703
# EE-217      -0.070137
# CS-421      -0.070337
# CS-210      -0.073924
# CS-318      -0.083949
# CS-423      -0.084136
# MT-331      -0.089948
# CS-301      -0.094668
# CS-403      -0.099369
# CS-312      -0.100055
# CS-306      -0.102412
# EL-332      -0.102678
# PH-121      -0.103905
# EL-102      -0.105427
# MT-224      -0.109234
# CS-317      -0.114741
# MT-111      -0.114907
# CS-107      -0.128700
# HS-101      -0.137673
# CS-203      -0.147770
# HS-105/12   -0.149337
# TC-383      -0.156384
# CS-215      -0.166539
# MT-222      -0.172293
# CS-211      -0.182940
# CS-214      -0.187985
# ME-107      -0.188588
# ...

# %% [markdown]
# Observation : Skewness in range of (-0.1 to +0.0). Now We can do scaling

# %% [markdown]
# # Feature Scaling :

# %%
# Scaling increases the model performance to much extent, we get best result after scaling data

# %%
# Standard Scaling :

from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x)
x1
# Out:
# array([[ 0.56128983,  1.67473424,  1.41859124, ...,  1.58609347,
#         -0.1989044 , -0.30533145],
#        [-1.53065764,  1.35936594,  1.67610532, ...,  0.91653706,
#          0.78898872,  0.18007338],
#        [-1.53065764, -0.70688664, -1.27419722, ..., -1.92838387,
#         -0.60964378, -1.83058001],
#        ...,
#        [-0.04153262, -1.98470667,  0.04362548, ...,  0.16353993,
#         -0.60964378, -0.30533145],
#        [-1.53065764, -0.33373024,  1.55354794, ..., -0.25875796,
#          0.48900534,  1.247191  ],
#        [ 0.81556321,  1.35936594,  1.55354794, ...,  0.16353993,
#          1.57754608,  1.7850762 ]])

# %%
x=pd.DataFrame(x1,columns=x.columns)                                   #convert scaled data into DataFrame

# %%
# Multicollinearity Check VIF Technique

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)
    
vif_calc()
# Out:
#     VIF Factor   features
# 0     2.617331     PH-121
# 1     1.796043     HS-101
# 2     2.445325     CY-105
# 3     2.195001  HS-105/12
# 4     2.459751     MT-111
# 5     2.204387     CS-105
# 6     1.822645     CS-106
# 7     1.923333     EL-102
# 8     2.175976     EE-119
# 9     2.277738     ME-107
# 10    2.238152     CS-107
# 11    1.624350  HS-205/20
# 12    2.254786     MT-222
# 13    2.132589     EE-222
# 14    2.841845     MT-224
# 15    3.100204     CS-210
# 16    2.789814     CS-211
# 17    2.574153     CS-203
# 18    2.783475     CS-214
# 19    2.349988     EE-217
# 20    2.615506     CS-212
# 21    3.053316     CS-215
# 22    2.105396     MT-331
# 23    2.162300     EF-303
# 24    2.383649     HS-304
# 25    3.119708     CS-301
# 26    2.767016     CS-302
# 27    2.774032     TC-383
# 28    1.851272     MT-442
# 29    3.204387     EL-332
# 30    2.416114     CS-318
# 31    3.496703     CS-306
# 32    2.940620     CS-312
# 33    3.218651     CS-317
# ...

# %% [markdown]
# * Observation : As vif value < 5 so no multicollinearity present

# %% [markdown]
# # Outliers detection :

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.561290  1.674734  1.418591   0.647755  1.261253  1.838873  1.587946
# 1    1.530658  1.359366  1.676105   1.331851  0.511748  1.156812  1.587946
# 2    1.530658  0.706887  1.274197   0.386642  0.215952  1.368972  0.444804
# 3    1.463304  0.708810  1.676105   1.331851  1.478929  0.020426  1.834074
# 4    0.417037  1.099218  0.043625   0.101867  1.580537  1.368972  0.719166
# ..        ...       ...       ...        ...       ...       ...       ...
# 566  0.041533  1.984707  1.274197   0.574628  0.958828  1.368972  0.719166
# 567  0.882125  1.984707  1.274197   1.570415  1.580537  1.368972  1.927057
# 568  0.041533  1.984707  0.043625   0.101867  1.580537  1.368972  1.927057
# 569  1.530658  0.333730  1.553548   1.570415  1.478929  1.838873  0.444804
# 570  0.815563  1.359366  1.553548   0.647755  0.781051  1.838873  0.282588
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
# Removing outliers from x

df1=df[(z<3).all(axis=1)]
df1
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %% [markdown]
# # Train and Test Splitting :

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=3)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((571, 41), (399, 41), (172, 41))

# %% [markdown]
# # Modelling :

# %% [markdown]
# Metrics imported :

# %%
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# 1. LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)                                                          #fitting the data will train your model
# Out:
# LinearRegression()

# %% [markdown]
# Our Model is successfully trained , Lets perform prediction

# %%
pred_train_lr=lr.predict(x_train)
predlr=lr.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_lr))
print('Testing Accuracy is',r2_score(y_test,predlr))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predlr))
print('Mean squared Error:',mean_squared_error(y_test,predlr))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# Training Accuracy is 0.9042295869410151
# Testing Accuracy is 0.9072312586473764
# Error:
# Mean Absolute Error: 0.12691976683348097
# Mean squared Error: 0.036972338480498766
# Root Mean squared Error: 0.19228192447679207

# %%
from sklearn.model_selection import cross_val_score
cr_1=cross_val_score(lr,x,y,cv=6)
print("Cross Validation Score of Linear Regression model:-",cr_1.mean())
diff_1=r2_score(y_test,predlr)-cr_1.mean()
print("diff between r2 score and cross validation score is -",diff_1)
# Out:
# Cross Validation Score of Linear Regression model:- 0.8755335477495367
# diff between r2 score and cross validation score is - 0.03169771089783968

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge                 #Alpha Value should be same for all regression

# %% [markdown]
# 2. Lasso Regression

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)                                     #Fitting Training Model
ls_score_training=ls.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 90.42271381748664

# %%
pred_train_ls=ls.predict(x_train)
predls=ls.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_ls))
print('Testing Accuracy is',r2_score(y_test,predls))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predls))
print('Mean squared Error:',mean_squared_error(y_test,predls))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# Training Accuracy is 0.9042271381748663
# Testing Accuracy is 0.9074993354273423
# Error:
# Mean Absolute Error: 0.1266420718370253
# Mean squared Error: 0.03686549833905514
# Root Mean squared Error: 0.1920039018849751

# %%
from sklearn.model_selection import cross_val_score
cr_2=cross_val_score(ls,x,y,cv=6)
print("Cross Validation Score of Lasso model:-",cr_2.mean())
diff_2=r2_score(y_test,predls)-cr_1.mean()
print("diff between r2 score and cross validation score is -",diff_2)
# Out:
# Cross Validation Score of Lasso model:- 0.8756043339862237
# diff between r2 score and cross validation score is - 0.03196578767780556

# %% [markdown]
# 3. Ridge Regression

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)                                     #Fitting Training Model
rd_score_training=rd.score(x_train,y_train)
print((ls_score_training)*100)
# Out:
# 90.42271381748664

# %%
pred_train_rd=rd.predict(x_train)
predrd=rd.predict(x_test)                                   #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rd))
print('Testing Accuracy is',r2_score(y_test,predrd))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrd))
print('Mean squared Error:',mean_squared_error(y_test,predrd))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# Training Accuracy is 0.9042295869410008
# Testing Accuracy is 0.9072312871501441
# Error:
# Mean Absolute Error: 0.12691973683281185
# Mean squared Error: 0.03697232712091838
# Root Mean squared Error: 0.1922818949379228

# %%
cr_3=cross_val_score(rd,x,y,cv=6)
print("Cross Validation Score of Ridge model:-",cr_3.mean())
diff_3=r2_score(y_test,predrd)-cr_3.mean()
print("diff between r2 score and cross validation score is -",diff_3)
# Out:
# Cross Validation Score of Ridge model:- 0.8755335654462636
# diff between r2 score and cross validation score is - 0.03169772170388052

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# To make our model more perfect we try another method 4) RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_train_rf=rf.predict(x_train)
predrf=rf.predict(x_test)                                                       #predicted variable for testing

print('Training Accuracy is',r2_score(y_train,pred_train_rf))
print('Testing Accuracy is',r2_score(y_test,predrf))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,predrf))
print('Mean squared Error:',mean_squared_error(y_test,predrf))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# Training Accuracy is 0.9874629204656754
# Testing Accuracy is 0.9441901701934419
# Error:
# Mean Absolute Error: 0.10479424418604646
# Mean squared Error: 0.022242620607558126
# Root Mean squared Error: 0.14913960107080254

# %%
cr_4=cross_val_score(rf,x,y,cv=6)
print("Cross Validation Score of Random Forest Regressor model:-",cr_4.mean())
diff_4=r2_score(y_test,predrf)-cr_4.mean()
print("diff between r2 score and cross validation score is -",diff_4)
# Out:
# Cross Validation Score of Random Forest Regressor model:- 0.9127497212171778
# diff between r2 score and cross validation score is - 0.03144044897626408

# %%
result = pd.DataFrame({'Models':['Lr','ls','rd','rf'],
                       'r2_score':[r2_score(y_test,predlr)*100,
                                   r2_score(y_test,predls)*100,
                                   r2_score(y_test,predrd)*100,
                                   r2_score(y_test,predrf)*100],
                     'Difference of r2_score and cross-val':[diff_1,diff_2,diff_3,diff_4]})
result
# Out:
#   Models   r2_score  Difference of r2_score and cross-val
# 0     Lr  90.723126                              0.031698
# 1     ls  90.749934                              0.031966
# 2     rd  90.723129                              0.031698
# 3     rf  94.419017                              0.031440

# %% [markdown]
# # Save Model

# %% [markdown]
# We are saving Random Forest model as our best model

# %%
import joblib

joblib.dump(rf,'student_grade_prediction')
# Out:
# ['student_grade_prediction']

# %% [markdown]
# # Load Model

# %%
model=joblib.load('student_grade_prediction')

# %% [markdown]
# # Prediction Model

# %%
input_data=(3,0,2,5,0,5,5,0,2,3,2,4,1,3,7,6,4,2,4,1,4,5,2,1,5,1,5,3,4,3,2,0,4,5,0,6,3,0,5,5,4)

# Changing data into numpy array
input_data_nparray=np.asarray(input_data)

# reshaping data as we are predicting label for only one instance
input_data_reshaped=input_data_nparray.reshape(1,-1)

prediction=model.predict(input_data_reshaped)
print(prediction)
# Out:
# [1.75078]

# %% [markdown]
# Hence Student Grade 'CGPA' predicted
