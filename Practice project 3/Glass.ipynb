# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("glass.csv",names=['Id number','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type_of_glass'])
df
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type_of_glass
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7
#
# [214 rows x 11 columns]

# %% [markdown]
# Checking No of Rows and columns :

# %%
df=df.drop(['Id number'],axis=1)                                     # Id number is nominal data so we can drop it
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type_of_glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...            ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0              7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0              7
#
# [214 rows x 10 columns]

# %%
df.shape
# Out:
# (214, 10)

# %%
# First 5 rows of dataset :
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type_of_glass
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0              1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0              1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0              1

# %%
# Last 5 rows of dataset :
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type_of_glass
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0              7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0              7

# %%
# Checking columns name:
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type_of_glass'], dtype='object')

# %%
# Checking datatypes of all columns :
df.dtypes
# Out:
# RI               float64
# Na               float64
# Mg               float64
# Al               float64
# Si               float64
# K                float64
# Ca               float64
# Ba               float64
# Fe               float64
# Type_of_glass      int64
# dtype: object

# %% [markdown]
# #Observation : No need of encoding as all data is int /float

# %%
# Checking Missing values in dataset :

df.isnull().sum()
# Out:
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type_of_glass    0
# dtype: int64

# %% [markdown]
# There is no missing values so it is good , otherwise we have to treat missing values

# %% [markdown]
# # Heatmap of Null Values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Data Analysis and Visulization

# %% [markdown]
# Statistical measure of dataset :

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type_of_glass
# count  214.000000  214.000000  214.000000     214.000000
# mean     8.956963    0.175047    0.057009       2.780374
# std      1.423153    0.497219    0.097439       2.103739
# min      5.430000    0.000000    0.000000       1.000000
# 25%      8.240000    0.000000    0.000000       1.000000
# 50%      8.600000    0.000000    0.000000       2.000000
# 75%      9.172500    0.000000    0.100000       3.000000
# max     16.190000    3.150000    0.510000       7.000000

# %% [markdown]
# All statistical data of all rows shown for each parameters like mean, minimum, maximum , 25th percentile means how much value for each column are below 25th percentile ,similarly for 50th perecntile and 75th perecntile.

# %%
# Checking unique values for output

df.Type_of_glass.unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
# Count no for each type of class values :

df.Type_of_glass.value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type_of_glass, dtype: int64

# %%
#Above result can be shown in graph through catplot / countplot as classification type data

# %%
sns.countplot(x='Type_of_glass',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='count'>

# %% [markdown]
# * Observation : Quantities shown for each class quality

# %% [markdown]
# # EDA

# %%
#Univariate Analysis

# As data is continuous or integer so we draw density plot

# %%
sns.distplot(df['RI'])
# Out:
# <Axes: xlabel='RI', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 1.51-1.52 and it is right skewed data.

# %%
sns.distplot(df['Na'])
# Out:
# <Axes: xlabel='Na', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 13-15 and it is right skewed data.

# %%
sns.distplot(df['Mg'])
# Out:
# <Axes: xlabel='Mg', ylabel='Density'>

# %%
sns.distplot(df['Al'])
# Out:
# <Axes: xlabel='Al', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 1-2 and it is bell shaped curve

# %%
sns.distplot(df['Si'])
# Out:
# <Axes: xlabel='Si', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 72-74 and it is left skewed data.

# %%
sns.distplot(df['K'])
# Out:
# <Axes: xlabel='K', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 0-1 and it is slightly left skewed data.

# %%
sns.distplot(df['Ca'])
# Out:
# <Axes: xlabel='Ca', ylabel='Density'>

# %% [markdown]
# * Observation : Data lies between values 8-10 and it is right skewed data.

# %%
sns.distplot(df['Ba'])
# Out:
# <Axes: xlabel='Ba', ylabel='Density'>

# %% [markdown]
# * Observation : Data is symmetric

# %%
sns.distplot(df['Fe'])
# Out:
# <Axes: xlabel='Fe', ylabel='Density'>

# %% [markdown]
# * Observation : Data is symmetric , little bit right skewness

# %% [markdown]
# * BIVARIATE ANALYSIS

# %% [markdown]
# We check input parameters with output measure "Type_of_glass" through Bar Plots :

# %%
# RI vs Type_of_glass

sns.barplot(x='Type_of_glass',y='RI',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='RI'>

# %% [markdown]
# * Observation : There is direct relation . As RI value increases , glass quality increases

# %%
# Na vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Na',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Na'>

# %% [markdown]
# * Observation : There is direct relation . As Na value increases , glass quality increases

# %%
# Mg vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Mg',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Mg'>

# %% [markdown]
# * Observation : There is invserse relation . As Mg value increases , glass quality decreases

# %%
# Al vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Al',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Al'>

# %% [markdown]
# * Observation : There is direct relation . As Al value increases , glass quality increases

# %%
# Si vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Si',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Si'>

# %% [markdown]
# * Observation : There is direct relation . As Si value increases , glass quality increases

# %%
# K vs Type_of_glass

sns.barplot(x='Type_of_glass',y='K',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='K'>

# %% [markdown]
# * Observation : There is not any clear relation

# %%
# Ca vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Ca',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Ca'>

# %% [markdown]
# * Observation : There is inverse relation . As Ca value increases , glass quality decreases

# %%
# Ba vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Ba',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Ba'>

# %% [markdown]
# * Observation : There is direct relation . As Ba value increases , glass quality increases

# %%
# Fe vs Type_of_glass

sns.barplot(x='Type_of_glass',y='Fe',data=df)
# Out:
# <Axes: xlabel='Type_of_glass', ylabel='Fe'>

# %% [markdown]
# * Observation : There is inverse relation . As Fe value increases , glass quality increases

# %%
## SCATTER PLOT

# %%
plt.scatter(df['RI'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 1515 to 1528

# %%
plt.scatter(df['Na'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 12 to 15

# %%
plt.scatter(df['Mg'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 3 to 4

# %%
plt.scatter(df['Al'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 0.5 to 2.0

# %%
plt.scatter(df['Si'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 72 to 74

# %%
plt.scatter(df['K'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 0 to 1

# %%
plt.scatter(df['Ca'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 8 to 10

# %%
plt.scatter(df['Ba'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 0.5 to 1.5

# %%
plt.scatter(df['Fe'],df['Type_of_glass'])

# %% [markdown]
# #Obervation : Data mainly present in points 0.1 to 0.3

# %%
## Multivariate Analysis

# %%
df.plot(kind='density',subplots=True,layout=(2,6),sharex=False,legend=True,figsize=(18,10))
plt.show()

# %%
#Observation : As datas are not perfectly well shaped curved,so have to remove skewness

# %% [markdown]
# # Correlation :

# %%
#Now we check correlation of input parameters with output "quality" :
#positively correlated : direct correlation
#negatively correlated : negative correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                      RI        Na        Mg        Al        Si         K  \
# RI             1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833
# Na            -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087
# Mg            -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396
# Al            -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958
# Si            -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331
# K             -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000
# Ca             0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836
# Ba            -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618
# Fe             0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719
# Type_of_glass -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054
#
#                      Ca        Ba        Fe  Type_of_glass
# RI             0.810403 -0.000386  0.143010      -0.164237
# Na            -0.275442  0.326603 -0.241346       0.502898
# Mg            -0.443750 -0.492262  0.083060      -0.744993
# Al            -0.259592  0.479404 -0.074402       0.598829
# Si            -0.208732 -0.102151 -0.094201       0.151565
# K             -0.317836 -0.042618 -0.007719      -0.010054
# Ca             1.000000 -0.112841  0.124968       0.000952
# Ba            -0.112841  1.000000 -0.058692       0.575161
# Fe             0.124968 -0.058692  1.000000      -0.188278
# Type_of_glass  0.000952  0.575161 -0.188278       1.000000

# %%
# For better understanding of correlation matrix between columns we draw heatmap :

plt.figure(figsize=(10,5))
sns.heatmap(dfcor,annot=True)
# Out:
# <Axes: >

# %%
# We can change color also and decimal values place :

plt.figure(figsize=(8,6))
sns.heatmap(dfcor,annot=True,cmap='Blues',fmt='0.2f',cbar=True,square=False)
# Out:
# <Axes: >

# %% [markdown]
# Observation : We can directly see for Type_of_glass , Id number is directly positively correlated as value = 0.88 and Mg is inverse as negative correlated value = - 0.74

# %% [markdown]
# # Data Preprocessing

# %%
df['Type_of_glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
## Binarization of Target Variable ##
#Arbitary Cut-Off set

# %%
df['Type_of_glass']=[1 if x<=4 else 0 for x in df['Type_of_glass']]   # arbitary cut-off taken, 1-> window glass and 0 -> non-window glass

# %%
df['Type_of_glass'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # Handling imbalanced data :

# %% [markdown]
# Split x and y

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    0
# 210    0
# 211    0
# 212    0
# 213    0
# Name: Type_of_glass, Length: 214, dtype: int64

# %%
# Oversampling

from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)
y.value_counts()
# Out:
# 1    163
# 0    163
# Name: Type_of_glass, dtype: int64

# %% [markdown]
# Now Data is balanced here

# %% [markdown]
# # Skewness :

# %%
x.skew().sort_values(ascending=False)
# Out:
# K     5.140218
# Fe    2.298600
# Ba    1.847590
# Ca    1.351673
# RI    1.282536
# Al    0.325345
# Na    0.052238
# Mg   -0.272578
# Si   -0.951131
# dtype: float64

# %% [markdown]
# *Observation : High skewness present in K and Fe and little in some parameters also so we apply Transformation.

# %%
#Remove Skewness - apply power transformation

from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[ 0.        , -0.0488059 ,  1.42311405, ..., -0.09243998,
#         -0.68597577, -0.61626957],
#        [ 0.        ,  0.23769743,  0.96142173, ..., -0.86023331,
#         -0.68597577, -0.61626957],
#        [ 0.        , -0.17507829,  0.93483717, ..., -0.90536729,
#         -0.68597577, -0.61626957],
#        ...,
#        [ 0.        ,  0.66591235,  0.19256174, ...,  0.31089589,
#         -0.68597577, -0.61626957],
#        [ 0.        ,  0.34772018,  0.22307801, ...,  0.44084162,
#         -0.68597577, -0.61626957],
#        [ 0.        ,  1.25215496, -1.26676044, ...,  0.00235596,
#          1.36627594, -0.61626957]])

# %%
x=pd.DataFrame(x_new,columns=x.columns)                                        #convert transformed data into DataFrame

# %%
#after transformation check skewness

# %%
x.skew().sort_values(ascending=False)
# Out:
# Fe    1.135676
# Ba    0.856889
# Si    0.169795
# K     0.136736
# Na    0.016222
# Al    0.007555
# RI    0.000000
# Ca   -0.063539
# Mg   -0.319061
# dtype: float64

# %% [markdown]
# Observation : As data is distributed normally to much extent in range of (-0.0 to +0.9). Skewness Removed otherwise we can use Power Tranfsormer method also. Now We can do scaling

# %% [markdown]
# # Feature Scaling :

# %%
# Scaling increases the model performance to much extent, we get best result after scaling data

# %%
# Standard Scaling :

from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x)
x1
# Out:
# array([[ 0.06365941, -0.0488059 ,  1.42311405, ..., -0.09243998,
#         -0.68597577, -0.61626957],
#        [ 0.06365941,  0.23769743,  0.96142173, ..., -0.86023331,
#         -0.68597577, -0.61626957],
#        [ 0.06365941, -0.17507829,  0.93483717, ..., -0.90536729,
#         -0.68597577, -0.61626957],
#        ...,
#        [ 0.06365941,  0.66591235,  0.19256174, ...,  0.31089589,
#         -0.68597577, -0.61626957],
#        [ 0.06365941,  0.34772018,  0.22307801, ...,  0.44084162,
#         -0.68597577, -0.61626957],
#        [ 0.06365941,  1.25215496, -1.26676044, ...,  0.00235596,
#          1.36627594, -0.61626957]])

# %%
x=pd.DataFrame(x1,columns=x.columns)                                   #convert scaled data into DataFrame

# %%
# Multicollinearity Check VIF Technique

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)
    
vif_calc()
# Out:
#    VIF Factor features
# 0    1.863904       RI
# 1    4.300357       Na
# 2    7.271200       Mg
# 3    2.684598       Al
# 4    2.006568       Si
# 5    5.100272        K
# 6    7.720060       Ca
# 7    5.042857       Ba
# 8    1.070872       Fe

# %% [markdown]
# Observation : As vif value < 10 so no multicollinearity present

# %% [markdown]
# # Outliers detection :

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.063659  0.048806  1.423114  0.998006  1.276720  0.883808  0.092440
# 1    0.063659  0.237697  0.961422  0.458444  0.077833  0.552375  0.860233
# 2    0.063659  0.175078  0.934837  0.101519  0.296839  0.334372  0.905367
# 3    0.063659  0.543162  1.009088  0.600771  0.243619  0.739560  0.520816
# 4    0.063659  0.474061  0.972035  0.703718  0.431628  0.700307  0.648782
# ..        ...       ...       ...       ...       ...       ...       ...
# 321  0.063659  0.601617  1.266760  1.912498  0.784304  0.839842  0.151859
# 322  0.063659  1.336683  1.266760  1.301801  0.861076  1.217024  0.099472
# 323  0.063659  0.665912  0.192562  0.093645  0.347626  1.217024  0.310896
# 324  0.063659  0.347720  0.223078  0.185032  0.118091  1.217024  0.440842
# 325  0.063659  1.252155  1.266760  1.316391  0.750997  1.217024  0.002356
#
#            Ba        Fe
# 0    0.685976  0.616270
# 1    0.685976  0.616270
# 2    0.685976  0.616270
# 3    0.685976  0.616270
# 4    0.685976  0.616270
# ..        ...       ...
# 321  1.324530  0.753512
# 322  1.354209  0.616270
# 323  0.685976  0.616270
# 324  0.685976  0.616270
# 325  1.366276  0.616270
#
# [326 rows x 9 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 47,  56, 103, 106, 106, 106, 107, 107, 110, 110, 111, 111, 111,
#        112, 112, 163, 163, 166, 171, 172, 180, 180, 184, 184, 184, 185,
#        185, 186, 201, 214, 220, 220, 240, 240, 252, 252, 252, 262, 262,
#        280, 291], dtype=int64), array([0, 0, 0, 0, 1, 4, 0, 6, 0, 6, 0, 1, 6, 0, 6, 3, 4, 1, 0, 0, 0, 4,
#        0, 1, 4, 0, 6, 6, 4, 0, 0, 6, 0, 6, 0, 1, 4, 0, 6, 0, 6],
#       dtype=int64))

# %%
# Removing outliers from x

df1=df[(z<3).all(axis=1)]
df1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type_of_glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...            ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0              0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0              0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0              0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0              0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0              0
#
# [197 rows x 10 columns]

# %%
#After outliers removal some rows are removed so check data loss :-

# %%
# % Data Loss

data_loss=(214-202)/214100
print(data_loss)
# Out:
# 5.6048575432041104e-05

# %% [markdown]
# We can proceed as not high data loss

# %% [markdown]
# # Train and Test Splitting :

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=2)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((326, 9), (260, 9), (66, 9))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((326,), (260,), (66,))

# %% [markdown]
# # Modelling :

# %% [markdown]
# Metrics imported :

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# 1. LOGISTICS REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()

LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Our Model is successfully trained , Lets perform prediction

# %%
pred_train_lr=LR.predict(x_train)
predlr=LR.predict(x_test)
print("Training Accuracy",accuracy_score(y_train,pred_train_lr)*100) 
print("Testing Accuracy:-",accuracy_score(y_test,predlr)*100)                               #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predlr))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predlr))                    # Take Classification report as CR
# Out:
# Training Accuracy 96.53846153846153
# Testing Accuracy:- 98.48484848484848
# CM:- [[35  0]
#  [ 1 30]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        35
#            1       1.00      0.97      0.98        31
#
#     accuracy                           0.98        66
#    macro avg       0.99      0.98      0.98        66
# weighted avg       0.99      0.98      0.98        66

# %%
from sklearn.model_selection import cross_val_score
cr_1=cross_val_score(LR,x,y,cv=7)
print("Cross Validation Score of Logistic Regression model:-",cr_1.mean())
diff_1=accuracy_score(y_test,predlr)-cr_1.mean()
print("diff between accuracy score and cross validation score is -",diff_1)
# Out:
# Cross Validation Score of Logistic Regression model:- 0.9323377824765429
# diff between accuracy score and cross validation score is - 0.052510702371942

# %% [markdown]
# * Apply More Classifiers :

# %% [markdown]
# 2. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_train_dtc=dt.predict(x_train)
preddt=dt.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_dtc)*100) 
print("Testing Accuracy",accuracy_score(y_test,preddt)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,preddt))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,preddt))                    # Take Classification report as CR
# Out:
# Training Accuracy 100.0
# Testing Accuracy 93.93939393939394
# CM:- [[32  3]
#  [ 1 30]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        35
#            1       0.91      0.97      0.94        31
#
#     accuracy                           0.94        66
#    macro avg       0.94      0.94      0.94        66
# weighted avg       0.94      0.94      0.94        66

# %%
from sklearn.model_selection import cross_val_score
cr_2=cross_val_score(dt,x,y,cv=7)
print("Cross Validation Score of Decision Tree Classifier:-",cr_2.mean())
diff_2=accuracy_score(y_test,preddt)-cr_2.mean()
print("diff between accuracy score and cross validation score is -",diff_2)
# Out:
# Cross Validation Score of Decision Tree Classifier:- 0.929232192414431
# diff between accuracy score and cross validation score is - 0.010161746979508446

# %% [markdown]
# 3. Support Vector Classifier

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred_train_svc=svc.predict(x_train)
predsvc=svc.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_svc)*100) 
print("Testing Accuracy",accuracy_score(y_test,predsvc)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predsvc))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predsvc))                    # Take Classification report as CR
# Out:
# Training Accuracy 97.6923076923077
# Testing Accuracy 98.48484848484848
# CM:- [[34  1]
#  [ 0 31]]
# CR:-               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        35
#            1       0.97      1.00      0.98        31
#
#     accuracy                           0.98        66
#    macro avg       0.98      0.99      0.98        66
# weighted avg       0.99      0.98      0.98        66

# %%
from sklearn.model_selection import cross_val_score
cr_3=cross_val_score(svc,x,y,cv=7)
print("Cross Validation Score of Support Vector Classifier:-",cr_3.mean())
diff_3=accuracy_score(y_test,predsvc)-cr_3.mean()
print("diff between accuracy score and cross validation score is -",diff_3)
# Out:
# Cross Validation Score of Support Vector Classifier:- 0.9382185806792653
# diff between accuracy score and cross validation score is - 0.04662990416921953

# %% [markdown]
# 4. MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

mnb=MultinomialNB()
mnb.fit(abs(x_train),y_train)
# Out:
# MultinomialNB()

# %%
pred_train_mnb=mnb.predict(x_train)
predmnb=mnb.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_mnb)*100) 
print("Testing Accuracy",accuracy_score(y_test,predmnb)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predmnb))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predmnb))                    # Take Classification report as CR
# Out:
# Training Accuracy 81.53846153846153
# Testing Accuracy 75.75757575757575
# CM:- [[26  9]
#  [ 7 24]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76        35
#            1       0.73      0.77      0.75        31
#
#     accuracy                           0.76        66
#    macro avg       0.76      0.76      0.76        66
# weighted avg       0.76      0.76      0.76        66

# %%
from sklearn.model_selection import cross_val_score
cr_4=cross_val_score(mnb,abs(x),y,cv=7)
print("Cross Validation Score of MultinomialNB:-",cr_4.mean())
diff_4=accuracy_score(y_test,predmnb)-cr_4.mean()
print("diff between accuracy score and cross validation score is -",diff_4)
# Out:
# Cross Validation Score of MultinomialNB:- 0.7058940134795824
# diff between accuracy score and cross validation score is - 0.05168174409617521

# %% [markdown]
# 5. KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()
knn.fit((x_train),y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_train_knn=knn.predict(x_train)
predknn=knn.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_knn)*100) 
print("Testing Accuracy",accuracy_score(y_test,predknn)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predknn))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predknn))                    # Take Classification report as CR
# Out:
# Training Accuracy 98.07692307692307
# Testing Accuracy 96.96969696969697
# CM:- [[34  1]
#  [ 1 30]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        35
#            1       0.97      0.97      0.97        31
#
#     accuracy                           0.97        66
#    macro avg       0.97      0.97      0.97        66
# weighted avg       0.97      0.97      0.97        66

# %%
from sklearn.model_selection import cross_val_score
cr_5=cross_val_score(knn,x,y,cv=7)
print("Cross Validation Score of KNeighbors Classifier:-",cr_5.mean())
diff_5=accuracy_score(y_test,predknn)-cr_5.mean()
print("diff between accuracy score and cross validation score is -",diff_5)
# Out:
# Cross Validation Score of KNeighbors Classifier:- 0.9599577111140478
# diff between accuracy score and cross validation score is - 0.009739258582921906

# %% [markdown]
# # Ensemble Method :

# %% [markdown]
# 6. Random Forest Classifier :

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_train_rf=rf.predict(x_train)
predrf=rf.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_rf)*100) 
print("Testing Accuracy",accuracy_score(y_test,predrf)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predrf))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predrf))                    # Take Classification report as CR
# Out:
# Training Accuracy 100.0
# Testing Accuracy 95.45454545454545
# CM:- [[33  2]
#  [ 1 30]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        35
#            1       0.94      0.97      0.95        31
#
#     accuracy                           0.95        66
#    macro avg       0.95      0.96      0.95        66
# weighted avg       0.96      0.95      0.95        66

# %%
from sklearn.model_selection import cross_val_score
cr_6=cross_val_score(rf,x,y,cv=7)
print("Cross Validation Score of Random Forest Classifier:-",cr_6.mean())
diff_6=accuracy_score(y_test,predrf)-cr_6.mean()
print("diff between accuracy score and cross validation score is -",diff_6)
# Out:
# Cross Validation Score of Random Forest Classifier:- 0.9505087881591118
# diff between accuracy score and cross validation score is - 0.004036666386342813

# %% [markdown]
# 7. Gradient Boosting Classifier:

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_train_gbc=gbc.predict(x_train)
predgbc=gbc.predict(x_test)

print("Training Accuracy",accuracy_score(y_train,pred_train_gbc)*100) 
print("Testing Accuracy",accuracy_score(y_test,predgbc)*100)            #Testing Accuracy
print("CM:-",confusion_matrix(y_test,predgbc))                         # Take Confusion matrix as CM
print("CR:-",classification_report(y_test,predgbc))                    # Take Classification report as CR
# Out:
# Training Accuracy 100.0
# Testing Accuracy 93.93939393939394
# CM:- [[33  2]
#  [ 2 29]]
# CR:-               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        35
#            1       0.94      0.94      0.94        31
#
#     accuracy                           0.94        66
#    macro avg       0.94      0.94      0.94        66
# weighted avg       0.94      0.94      0.94        66

# %%
from sklearn.model_selection import cross_val_score
cr_7=cross_val_score(gbc,x,y,cv=7)
print("Cross Validation Score of Gradient Boosting Classifier:-",cr_7.mean())
diff_7=accuracy_score(y_test,predgbc)-cr_7.mean()
print("diff between accuracy score and cross validation score is -",diff_7)
# Out:
# Cross Validation Score of Gradient Boosting Classifier:- 0.9476014272499008
# diff between accuracy score and cross validation score is - -0.00820748785596137

# %%
result = pd.DataFrame({'Models':['LR','dt','svc','mnb','knn','rf','gbc'],
                       'Accuracy':[accuracy_score(y_test,predlr)*100,
                                   accuracy_score(y_test,preddt)*100,
                                   accuracy_score(y_test,predsvc)*100,
                                   accuracy_score(y_test,predmnb)*100,
                                   accuracy_score(y_test,predknn)*100,
                                   accuracy_score(y_test,predrf)*100,
                                   accuracy_score(y_test,predgbc)*100],
                     'Difference of accuracy and cross-val':[diff_1,diff_2,diff_3,diff_4,diff_5,diff_6,diff_7]})
result
# Out:
#   Models   Accuracy  Difference of accuracy and cross-val
# 0     LR  98.484848                              0.052511
# 1     dt  93.939394                              0.010162
# 2    svc  98.484848                              0.046630
# 3    mnb  75.757576                              0.051682
# 4    knn  96.969697                              0.009739
# 5     rf  95.454545                              0.004037
# 6    gbc  93.939394                             -0.008207

# %% [markdown]
# Observation : Since our Support Vector Classifier is perfoming best among all as best accuracy and least difference. So we will continue with SVC.

# %% [markdown]
# # SAVE MODEL

# %%
import joblib

joblib.dump(knn,'glass_quality_prediction')
# Out:
# ['glass_quality_prediction']

# %%
model=joblib.load('glass_quality_prediction')

# %% [markdown]
# # Prediction on New Data

# %%
input_data=(1.51574,14.86,3.67,1.74,71.87,0.16,7.36,0.00,0.12)

# Changing data into numpy array
input_data_nparray=np.asarray(input_data)

# reshaping data as we are predicting label for only one instance
input_data_reshaped=input_data_nparray.reshape(1,-1)

prediction=model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
    print('Window Glass')
else:
    print('Non-Window Glass')
# Out:
# [0]
# Non-Window Glass

# %% [markdown]
# Hence glass (Window) Quality predicted
